# %%
import pandas
import duckdb

connection = duckdb.connect('novellia.duckdb')
connection.execute("SHOW TABLES").df()
# Out:
#                   name
# 0   allergyintolerance
# 1            condition
# 2               device
# 3     diagnosticreport
# 4    documentreference
# 5            encounter
# 6         immunization
# 7             location
# 8    medicationrequest
# 9          observation
# 10        organization
# 11             patient
# 12        practitioner
# 13    practitionerrole
# 14           procedure

# %%
connection.execute('''
SELECT
    *
FROM
    patient
''').df()
# Out:
#      resourceType                                    id  \
# 0         Patient  001ea705-d3ba-5329-0b27-a7fbde2f4007
# 1         Patient  006cce35-a7c1-71fc-e4e5-4ecc77920e61
# 2         Patient  008dd9b2-f541-d09f-1f67-cd741ece2254
# 3         Patient  00b7a058-8387-0c75-da63-7782ed4cc801
# 4         Patient  01004e47-23a4-35a8-d62c-5d9f685986b1
# ...           ...                                   ...
# 1139      Patient  fe9dae46-cd75-08a3-e516-b318157a1045
# 1140      Patient  fed27b28-8c8b-7937-db42-b3b9b16f0a47
# 1141      Patient  ff012ec1-1a5a-24d2-5008-8599e704b658
# 1142      Patient  ff14eb52-b973-e1f4-86d4-65adc19ce4d6
# 1143      Patient  ffe39562-f998-2ae1-3ec6-7d943c0eb50b
#
#                                                    meta  \
# 0     {'profile': ['http://hl7.org/fhir/us/core/Stru...
# 1     {'profile': ['http://hl7.org/fhir/us/core/Stru...
# 2     {'profile': ['http://hl7.org/fhir/us/core/Stru...
# 3     {'profile': ['http://hl7.org/fhir/us/core/Stru...
# ...
